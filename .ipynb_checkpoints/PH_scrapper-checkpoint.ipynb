# %%
pip install graphqlclient
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for graphqlclient: filename=graphqlclient-0.2.4-py3-none-any.whl size=3134 sha256=1800170a2d1f3ae363c7b013f0b2f4b5d90982324e71b65329a01cb10715f619
#   Stored in directory: /Users/ivanhusarov/Library/Caches/pip/wheels/28/82/aa/a17f0155204dd9b0d3666ba074d763ffeb679811d3c74205f7
# Successfully built graphqlclient
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json


body = {
    "client_id": 'JtzePi8aSIlHqH3yrkQHB0LHFzrZiE_sQSBnoxr4s9k',
    "client_secret": 'WODVJ3oTu0clUwVF0kE9if4-pjcXb_aNGrbLUXTr2mI',
    "grant_type": 'client_credentials'
}

res = requests.post("https://api.producthunt.com/v2/oauth/token", json=body)

# %%
res.content
# Out:
# b'{"access_token":"80lsUlx0NhU4tskes86Tj7oF_YnQHv40YJf2ZOqWaa0","token_type":"Bearer","scope":"public","created_at":1720113564}'

# %%
from gql import Client, gql
from gql.transport.requests import RequestsHTTPTransport
from datetime import datetime

transport = RequestsHTTPTransport(
    url='https://api.producthunt.com/v2/api/graphql',
    headers={'Authorization': 'Bearer 80lsUlx0NhU4tskes86Tj7oF_YnQHv40YJf2ZOqWaa0'}
)

client = Client(transport=transport, fetch_schema_from_transport=True)

query = gql("""
query fetchPosts($postedBefore: DateTime, $postedAfter: DateTime, $after: String){
  posts(postedBefore:$postedBefore, postedAfter:$postedAfter, after:$after) {
    pageInfo {
      hasNextPage,
      endCursor
    }
    nodes {
      id,
      name,
      votesCount,
      commentsCount,
      tagline,
      createdAt,
      description,
      topics{
        totalCount,
        nodes{
          name,
        }
      },
    }
  }
}
""")

posted_before_str, posted_after_str = ("2024-06-25", "2024-06-24")

variables = {"postedBefore": "2024-06-25", "postedAfter": "2024-06-24"}

result = client.execute(query, variable_values=variables)
# print(json.dumps(result, indent=4))

# result["posts"]["pageInfo"]["hasNextPage"]
result["posts"]["nodes"]
# Out:
# [{'id': '465127',
#   'name': 'Pygma',
#   'votesCount': 1521,
#   'commentsCount': 278,
#   'tagline': 'AI copilot for Instagram',
#   'createdAt': '2024-06-24T07:01:00Z',
#   'description': "First - I'll analyze your Instagram profile data and save the vibe. Second - give you 7 days of content ideas that could be interesting to your audience. Then I'll create personalized content for you and suggest scheduling it to your profile directly from UI.",
#   'topics': {'totalCount': 3,
#    'nodes': [{'name': 'Instagram'},
#     {'name': 'Social Media'},
#     {'name': 'Artificial Intelligence'}]}},
#  {'id': '464535',
#   'name': 'revid.ai',
#   'votesCount': 986,
#   'commentsCount': 253,
#   'tagline': 'All-in-one tool to create viral short videos',
#   'createdAt': '2024-06-24T07:01:00Z',
# ...

# %%
import pandas as pd    

df = pd.json_normalize(result["posts"]["nodes"])

# %%
df.to_csv('ProductHuntProducts.csv', mode='a', index=False, header=False)

# %%
from datetime import datetime, timedelta
import pandas as pd    

def from_iso(iso_str):
    return datetime.strptime(iso_str, "%Y-%m-%d").date()

def crawl_one_day(date, after_cursor=""):
    posted_after = date.isoformat()
    posted_before = (date + timedelta(days=1)).isoformat()

    # print(posted_before, posted_after, after_cursor)
    variables = {"postedBefore": posted_before, "postedAfter": posted_after, "after": after_cursor}

    result = client.execute(query, variable_values=variables)

    if(result["posts"]["pageInfo"]["hasNextPage"]):
        next_nodes = crawl_one_day(date, result["posts"]["pageInfo"]["endCursor"])
        return result["posts"]["nodes"] + next_nodes
    
    return result["posts"]["nodes"] 

def append_result(result):
    df = pd.json_normalize(result)
    df.drop_duplicates(subset='id', keep="first", inplace=True)
    df.to_csv('ProductHuntProducts.csv', mode='a', index=False, header=False)

# %%
day_one = crawl_one_day(from_iso("2024-07-09"))
# Out:
# 2024-07-10 2024-07-09
# 2024-07-10 2024-07-09 MjA
# 2024-07-10 2024-07-09 NDA
# 2024-07-10 2024-07-09 NjA
# 2024-07-10 2024-07-09 ODA
# 2024-07-10 2024-07-09 MTAw
# 2024-07-10 2024-07-09 MTIw
# 2024-07-10 2024-07-09 MTQw
# 2024-07-10 2024-07-09 MTYw

# %%
append_result(day_one)

# %%
df = pd.json_normalize(day_one)
df.drop_duplicates(subset='id', keep="first", inplace=True)
df
# Out:
#          id                       name  votesCount  commentsCount  \
# 0    461578                Airbook 2.0         729            194
# 1    466199                      Shram         521            223
# 2    468210       AI Agents by Threado         431            163
# 3    465883                    Krut AI         430            175
# 4    468352     StudioForm Pro Library         368            134
# ..      ...                        ...         ...            ...
# 151  469980       The Rebel Walk Forum           1              1
# 152  467963  Pixcap 3D Animated Icons          162             43
# 153  469990                     1Tribe           2              1
# 154  469503        https://i18nweb.com           4              1
# 159  469529    ZenWave: Binaural Beats           7              3
#
#                                                tagline             createdAt  \
# 0                      Think Notion, but for analytics  2024-07-09T07:01:00Z
# ...

# %%
from tqdm import tqdm
import pandas

# pandas.date_range(from_iso("2024-06-08"),from_iso("2024-07-08")-timedelta(days=1),freq='d')
sdate = from_iso("2024-04-15")
edate = from_iso("2024-05-15")
date_list = [sdate+timedelta(days=x) for x in range((edate-sdate).days)]
date_list.reverse()
# date_list

for day in tqdm(date_list):
    append_result(crawl_one_day(day))
# Out:
#  33%|█████████████████████████████████████████████████████████▎                                                                                                                  | 10/30 [00:24<00:49,  2.46s/it]
# ---------------------------------------------------------------------------
# TransportQueryError                       Traceback (most recent call last)
# Cell In[148], line 12
#       9 # date_list
#      11 for day in tqdm(date_list):
# ---> 12     append_result(crawl_one_day(day))
#
# Cell In[110], line 17, in crawl_one_day(date, after_cursor)
#      14 result = client.execute(query, variable_values=variables)
#      16 if(result["posts"]["pageInfo"]["hasNextPage"]):
# ---> 17     next_nodes = crawl_one_day(date, result["posts"]["pageInfo"]["endCursor"])
#      18     return result["posts"]["nodes"] + next_nodes
#      20 return result["posts"]["nodes"]
#
# Cell In[110], line 17, in crawl_one_day(date, after_cursor)
# ...

# %%
date_list
# Out:
# [datetime.date(2024, 6, 29),
#  datetime.date(2024, 6, 28),
#  datetime.date(2024, 6, 27),
#  datetime.date(2024, 6, 26),
#  datetime.date(2024, 6, 25),
#  datetime.date(2024, 6, 24),
#  datetime.date(2024, 6, 23),
#  datetime.date(2024, 6, 22),
#  datetime.date(2024, 6, 21),
#  datetime.date(2024, 6, 20),
#  datetime.date(2024, 6, 19),
#  datetime.date(2024, 6, 18),
#  datetime.date(2024, 6, 17),
#  datetime.date(2024, 6, 16),
#  datetime.date(2024, 6, 15),
#  datetime.date(2024, 6, 14),
#  datetime.date(2024, 6, 13),
#  datetime.date(2024, 6, 12),
#  datetime.date(2024, 6, 11),
#  datetime.date(2024, 6, 10),
#  datetime.date(2024, 6, 9),
#  datetime.date(2024, 6, 8),
#  datetime.date(2024, 6, 7),
#  datetime.date(2024, 6, 6),
#  datetime.date(2024, 6, 5),
#  datetime.date(2024, 6, 4),
#  datetime.date(2024, 6, 3),
#  datetime.date(2024, 6, 2),
#  datetime.date(2024, 6, 1),
#  datetime.date(2024, 5, 31),
#  datetime.date(2024, 5, 30)]
